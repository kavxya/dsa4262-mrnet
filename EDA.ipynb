# %%
import numpy as np
import os
from matplotlib import pyplot as plt
path = "data/valid/axial/"



files = [f for f in os.listdir(path)]

print(files[0])
# print(files)
img_array = np.load(path+files[0])


img_array.shape
# Out:
# 1139.npy
# (33, 256, 256)

# %%
len(img_array)
# Out:
# 33

# %%
middle = len(img_array)//2
img_array_mini = img_array[middle-1:middle+2]
img_array_mini.shape
# Out:
# (3, 256, 256)

# %%
plt.imshow(img_array[0], cmap='gray')

# %%
plt.imshow(img_array[1], cmap='gray')

# %%
plt.imshow(img_array[32], cmap='gray')  # Use 'cmap' to specify the color map (e.g., 'gray' for grayscale)
plt.show()

# %%
img_array_1 = np.load(path+"1154.npy")
plt.imshow(img_array_1[0], cmap='gray')
plt.show()

# %%
plt.imshow(img_array_1[1], cmap='gray')
plt.show()

# %%
plt.imshow(img_array_1[2], cmap='gray')
plt.show()

# %%
from PIL import Image
import numpy as np
data = np.load('imgs.npy')

data.shape

# %%
valid_label_path = "MRNet-v1.0/valid-abnormal.csv"
